# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, models
from torch.utils.data.sampler import SubsetRandomSampler
import os
import random
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
def process_data(datadir, valid_size = 0.25, batch_size = 128):
    
    train_transforms = transforms.Compose([transforms.Resize(227),transforms.ToTensor(),])
    test_transforms = transforms.Compose([transforms.Resize(227),transforms.ToTensor(),])
    
    train_data = datasets.ImageFolder(datadir, transform=train_transforms)
    test_data = datasets.ImageFolder(datadir, transform=test_transforms)
    
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size*num_train))
    np.random.shuffle(indices)
    train_idx,test_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(test_idx)
    
    trainloader = torch.utils.data.DataLoader(train_data, sampler = train_sampler, batch_size = batch_size)
    testloader = torch.utils.data.DataLoader(test_data, sampler = test_sampler, batch_size = batch_size)
    
    return trainloader,testloader

# %%
data_dir = "./data/mendeley"

train_loader,test_loader = process_data(data_dir)

# %%
class CNN_Model(nn.Module):
    def __init__(self):
        super().__init__()  
    
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=7, padding=1, stride=2),
            nn.LocalResponseNorm(size=5, alpha=0.0001, beta=0.75, k=2),
            nn.ReLU(inplace=False),
            nn.Conv2d(32, 64, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),          
            nn.Conv2d(64, 96, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm2d(96),
            nn.ReLU(inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),           
            nn.Conv2d(96, 128, kernel_size=5, padding=2, stride=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1, stride=1),
            nn.ReLU(inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(6272, 2048),
            nn.ReLU(inplace=False),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(2048, 512),
            nn.ReLU(inplace=False),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(512, 2),
        )    
        self.init_bias()
    
    def init_bias(self):
        for layer in self.features:
            if isinstance(layer, nn.Conv2d):
                nn.init.normal_(layer.weight, mean=0, std=0.01)
                nn.init.constant_(layer.bias, 0)        
    
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.shape[0], -1)
        x = self.classifier(x)
        return x

# %%
torch.cuda.empty_cache()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNN_Model().to(device)

# %%
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()

# %%
def accuracy(fp,y):
    preds = fp.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = correct.float()/preds.shape[0]
    return acc

# %%
def train(model, device, data_itr, optimizer, criterion):
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    for x,y in data_itr:
        x = x.to(device)
        y = y.to(device)
        
        optimizer.zero_grad()
        fp = model(x)
        loss = criterion(fp,y)
        acc = accuracy(fp,y)
        
        loss.backward()
        optimizer.step()
        
        epoch_loss += float(loss.item())
        epoch_acc += float(acc.item())
    return epoch_loss / len(data_itr), epoch_acc / len(data_itr)

# %%
def evaluate(model, device, data_itr, criterion):
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    with torch.no_grad():
        for x,y in data_itr:
            x = x.to(device)
            y = y.to(device)
            
            fp = model(x)
            loss = criterion(fp,y)
            acc = accuracy(fp,y)
            
            epoch_loss += loss.item()
            epoch_acc += acc.item()
    
    return epoch_loss / len(data_itr), epoch_acc / len(data_itr)

# %%
epochs = 1500
SAVE_DIR = 'models'
CKPT_SAVE_PATH = os.path.join(SAVE_DIR, 'cnn_crack_mendeleys.pth.tar')
MODEL_SAVE_PATH = os.path.join(SAVE_DIR, 'cnn_crack_mendeleys_model.pt')

best_val_loss = float('inf')

# if not os.path.isdir(f'{SAVE_DIR}'):
#     os.makedirs(f'{SAVE_DIR}')

Epochs = []
Training_loss = []
Training_accuracy = []
Validation_loss = []
Validation_accuracy = []
    
for epoch in range(epochs):
    to = time.time()
    train_loss,train_acc = train(model, device, train_loader, optimizer, criterion)
    val_loss,val_acc = evaluate(model, device, test_loader, criterion)
    tepoch = time.time() - to
    
    Epochs.append(epoch+1)
    Training_loss.append(train_loss)
    Training_accuracy.append(train_acc)
    Validation_accuracy.append(val_acc)
    Validation_loss.append(val_loss)
    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_epoch = epoch+1
        torch.save(model.state_dict(), MODEL_SAVE_PATH)
        
    if epoch%50 == 0:
        torch.save({
            'epoch': Epochs,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': Training_loss,
            'valid_loss': Validation_loss,
            'train_acc': Training_accuracy,
            'val_acc': Validation_accuracy,
            }, CKPT_SAVE_PATH)
        
    print("Epoch: %4d | Training loss: %.3f | Training Accuracy: %5.2f | Valid_loss: %.3f | Valid_accuracy: %5.2f | Time: %.3fsec" %(epoch+1, train_loss, train_acc*100, val_loss, val_acc*100, tepoch))

print((best_val_loss,best_epoch))
# Out:
# Epoch:    1 | Training loss: 0.070 | Training Accuracy: 97.80 | Valid_loss: 0.042 | Valid_accuracy: 98.52 | Time: 143.263sec
# Epoch:    2 | Training loss: 0.022 | Training Accuracy: 99.37 | Valid_loss: 0.030 | Valid_accuracy: 99.44 | Time: 141.905sec
# Epoch:    3 | Training loss: 0.020 | Training Accuracy: 99.50 | Valid_loss: 0.017 | Valid_accuracy: 99.51 | Time: 142.029sec
# Epoch:    4 | Training loss: 0.012 | Training Accuracy: 99.67 | Valid_loss: 0.314 | Valid_accuracy: 86.53 | Time: 141.998sec
# Epoch:    5 | Training loss: 0.010 | Training Accuracy: 99.74 | Valid_loss: 0.017 | Valid_accuracy: 99.59 | Time: 141.943sec
# Epoch:    6 | Training loss: 0.010 | Training Accuracy: 99.73 | Valid_loss: 0.007 | Valid_accuracy: 99.82 | Time: 141.857sec
# Epoch:    7 | Training loss: 0.007 | Training Accuracy: 99.78 | Valid_loss: 0.010 | Valid_accuracy: 99.74 | Time: 142.126sec
# Epoch:    8 | Training loss: 0.007 | Training Accuracy: 99.80 | Valid_loss: 0.010 | Valid_accuracy: 99.79 | Time: 142.099sec
# Epoch:    9 | Training loss: 0.007 | Training Accuracy: 99.81 | Valid_loss: 0.016 | Valid_accuracy: 99.64 | Time: 141.889sec
# Epoch:   10 | Training loss: 0.008 | Training Accuracy: 99.75 | Valid_loss: 0.150 | Valid_accuracy: 96.96 | Time: 142.076sec
# Epoch:   11 | Training loss: 0.008 | Training Accuracy: 99.79 | Valid_loss: 0.013 | Valid_accuracy: 99.66 | Time: 142.125sec
# Epoch:   12 | Training loss: 0.008 | Training Accuracy: 99.80 | Valid_loss: 0.007 | Valid_accuracy: 99.82 | Time: 142.007sec
# Epoch:   13 | Training loss: 0.004 | Training Accuracy: 99.89 | Valid_loss: 0.015 | Valid_accuracy: 99.77 | Time: 141.950sec
# Epoch:   14 | Training loss: 0.007 | Training Accuracy: 99.83 | Valid_loss: 0.010 | Valid_accuracy: 99.80 | Time: 142.036sec
# Epoch:   15 | Training loss: 0.007 | Training Accuracy: 99.79 | Valid_loss: 0.011 | Valid_accuracy: 99.73 | Time: 141.889sec
# Epoch:   16 | Training loss: 0.006 | Training Accuracy: 99.83 | Valid_loss: 0.037 | Valid_accuracy: 99.23 | Time: 141.826sec
# Epoch:   17 | Training loss: 0.006 | Training Accuracy: 99.86 | Valid_loss: 0.018 | Valid_accuracy: 99.74 | Time: 141.727sec
# Epoch:   18 | Training loss: 0.004 | Training Accuracy: 99.86 | Valid_loss: 0.013 | Valid_accuracy: 99.81 | Time: 141.496sec
# Epoch:   19 | Training loss: 0.003 | Training Accuracy: 99.90 | Valid_loss: 0.014 | Valid_accuracy: 99.74 | Time: 141.632sec
# Epoch:   20 | Training loss: 0.005 | Training Accuracy: 99.84 | Valid_loss: 0.016 | Valid_accuracy: 99.71 | Time: 141.723sec
# Epoch:   21 | Training loss: 0.004 | Training Accuracy: 99.87 | Valid_loss: 0.017 | Valid_accuracy: 99.75 | Time: 141.610sec
# Epoch:   22 | Training loss: 0.004 | Training Accuracy: 99.91 | Valid_loss: 0.010 | Valid_accuracy: 99.79 | Time: 141.820sec
# Epoch:   23 | Training loss: 0.008 | Training Accuracy: 99.77 | Valid_loss: 0.013 | Valid_accuracy: 99.69 | Time: 141.751sec
# Epoch:   24 | Training loss: 0.002 | Training Accuracy: 99.94 | Valid_loss: 0.033 | Valid_accuracy: 99.51 | Time: 141.671sec
# Epoch:   25 | Training loss: 0.001 | Training Accuracy: 99.95 | Valid_loss: 0.009 | Valid_accuracy: 99.82 | Time: 141.806sec
# Epoch:   26 | Training loss: 0.003 | Training Accuracy: 99.92 | Valid_loss: 0.038 | Valid_accuracy: 99.18 | Time: 141.957sec
# Epoch:   27 | Training loss: 0.005 | Training Accuracy: 99.88 | Valid_loss: 0.008 | Valid_accuracy: 99.83 | Time: 141.957sec
# Epoch:   28 | Training loss: 0.003 | Training Accuracy: 99.91 | Valid_loss: 0.012 | Valid_accuracy: 99.78 | Time: 141.918sec
# Epoch:   29 | Training loss: 0.005 | Training Accuracy: 99.84 | Valid_loss: 0.012 | Valid_accuracy: 99.59 | Time: 141.942sec
# Epoch:   30 | Training loss: 0.003 | Training Accuracy: 99.87 | Valid_loss: 0.012 | Valid_accuracy: 99.81 | Time: 141.771sec
# Epoch:   31 | Training loss: 0.003 | Training Accuracy: 99.90 | Valid_loss: 0.019 | Valid_accuracy: 99.79 | Time: 141.572sec
# Epoch:   32 | Training loss: 0.002 | Training Accuracy: 99.93 | Valid_loss: 0.016 | Valid_accuracy: 99.77 | Time: 141.611sec
# Epoch:   33 | Training loss: 0.003 | Training Accuracy: 99.92 | Valid_loss: 0.010 | Valid_accuracy: 99.81 | Time: 141.635sec
# Epoch:   34 | Training loss: 0.004 | Training Accuracy: 99.89 | Valid_loss: 0.013 | Valid_accuracy: 99.81 | Time: 141.734sec
# Epoch:   35 | Training loss: 0.002 | Training Accuracy: 99.94 | Valid_loss: 0.017 | Valid_accuracy: 99.67 | Time: 141.904sec
# Epoch:   36 | Training loss: 0.002 | Training Accuracy: 99.95 | Valid_loss: 0.024 | Valid_accuracy: 99.76 | Time: 141.625sec
# Epoch:   37 | Training loss: 0.004 | Training Accuracy: 99.92 | Valid_loss: 0.026 | Valid_accuracy: 99.37 | Time: 141.378sec
# Epoch:   38 | Training loss: 0.003 | Training Accuracy: 99.91 | Valid_loss: 0.018 | Valid_accuracy: 99.83 | Time: 141.556sec
# Epoch:   39 | Training loss: 0.004 | Training Accuracy: 99.89 | Valid_loss: 0.017 | Valid_accuracy: 99.78 | Time: 141.459sec
# Epoch:   40 | Training loss: 0.001 | Training Accuracy: 99.95 | Valid_loss: 0.012 | Valid_accuracy: 99.88 | Time: 141.207sec
# Epoch:   41 | Training loss: 0.000 | Training Accuracy: 99.98 | Valid_loss: 0.018 | Valid_accuracy: 99.81 | Time: 141.457sec
# Epoch:   42 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.039 | Valid_accuracy: 99.59 | Time: 141.331sec
# Epoch:   43 | Training loss: 0.003 | Training Accuracy: 99.91 | Valid_loss: 0.015 | Valid_accuracy: 99.76 | Time: 141.546sec
# Epoch:   44 | Training loss: 0.005 | Training Accuracy: 99.88 | Valid_loss: 0.019 | Valid_accuracy: 99.69 | Time: 141.552sec
# Epoch:   45 | Training loss: 0.001 | Training Accuracy: 99.96 | Valid_loss: 0.041 | Valid_accuracy: 99.50 | Time: 141.535sec
# Epoch:   46 | Training loss: 0.003 | Training Accuracy: 99.91 | Valid_loss: 0.013 | Valid_accuracy: 99.76 | Time: 141.327sec
# Epoch:   47 | Training loss: 0.003 | Training Accuracy: 99.90 | Valid_loss: 0.015 | Valid_accuracy: 99.78 | Time: 141.120sec
# Epoch:   48 | Training loss: 0.000 | Training Accuracy: 99.98 | Valid_loss: 0.019 | Valid_accuracy: 99.74 | Time: 140.918sec
# Epoch:   49 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.025 | Valid_accuracy: 99.80 | Time: 140.983sec
# Epoch:   50 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.025 | Valid_accuracy: 99.85 | Time: 141.196sec
# Epoch:   51 | Training loss: 0.004 | Training Accuracy: 99.90 | Valid_loss: 0.021 | Valid_accuracy: 99.79 | Time: 141.184sec
# Epoch:   52 | Training loss: 0.001 | Training Accuracy: 99.96 | Valid_loss: 0.020 | Valid_accuracy: 99.78 | Time: 140.932sec
# Epoch:   53 | Training loss: 0.003 | Training Accuracy: 99.94 | Valid_loss: 0.020 | Valid_accuracy: 99.78 | Time: 140.993sec
# Epoch:   54 | Training loss: 0.000 | Training Accuracy: 99.98 | Valid_loss: 0.023 | Valid_accuracy: 99.79 | Time: 141.235sec
# Epoch:   55 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.023 | Valid_accuracy: 99.84 | Time: 141.043sec
# Epoch:   56 | Training loss: 0.001 | Training Accuracy: 99.98 | Valid_loss: 0.024 | Valid_accuracy: 99.77 | Time: 141.030sec
# Epoch:   57 | Training loss: 0.004 | Training Accuracy: 99.92 | Valid_loss: 0.022 | Valid_accuracy: 99.79 | Time: 141.181sec
# Epoch:   58 | Training loss: 0.005 | Training Accuracy: 99.88 | Valid_loss: 0.040 | Valid_accuracy: 99.55 | Time: 141.433sec
# Epoch:   59 | Training loss: 0.004 | Training Accuracy: 99.91 | Valid_loss: 0.014 | Valid_accuracy: 99.88 | Time: 140.988sec
# Epoch:   60 | Training loss: 0.001 | Training Accuracy: 99.97 | Valid_loss: 0.027 | Valid_accuracy: 99.76 | Time: 141.174sec
# Epoch:   61 | Training loss: 0.002 | Training Accuracy: 99.95 | Valid_loss: 0.021 | Valid_accuracy: 99.77 | Time: 141.140sec
# Epoch:   62 | Training loss: 0.002 | Training Accuracy: 99.96 | Valid_loss: 0.016 | Valid_accuracy: 99.81 | Time: 141.171sec
# Epoch:   63 | Training loss: 0.002 | Training Accuracy: 99.94 | Valid_loss: 0.019 | Valid_accuracy: 99.85 | Time: 141.011sec
# Epoch:   64 | Training loss: 0.002 | Training Accuracy: 99.94 | Valid_loss: 0.018 | Valid_accuracy: 99.79 | Time: 141.040sec
# Epoch:   65 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.024 | Valid_accuracy: 99.81 | Time: 141.106sec
# Epoch:   66 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.029 | Valid_accuracy: 99.79 | Time: 141.257sec
# Epoch:   67 | Training loss: 0.004 | Training Accuracy: 99.92 | Valid_loss: 0.020 | Valid_accuracy: 99.84 | Time: 141.071sec
# Epoch:   68 | Training loss: 0.002 | Training Accuracy: 99.94 | Valid_loss: 0.020 | Valid_accuracy: 99.77 | Time: 140.867sec
# Epoch:   69 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.029 | Valid_accuracy: 99.83 | Time: 140.470sec
# Epoch:   70 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.026 | Valid_accuracy: 99.84 | Time: 140.422sec
# Epoch:   71 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.028 | Valid_accuracy: 99.84 | Time: 140.500sec
# Epoch:   72 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.026 | Valid_accuracy: 99.77 | Time: 140.711sec
# Epoch:   73 | Training loss: 0.001 | Training Accuracy: 99.97 | Valid_loss: 0.023 | Valid_accuracy: 99.79 | Time: 141.025sec
# Epoch:   74 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.028 | Valid_accuracy: 99.85 | Time: 140.938sec
# Epoch:   75 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.029 | Valid_accuracy: 99.86 | Time: 140.685sec
# Epoch:   76 | Training loss: 0.006 | Training Accuracy: 99.90 | Valid_loss: 0.016 | Valid_accuracy: 99.78 | Time: 140.787sec
# Epoch:   77 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.027 | Valid_accuracy: 99.72 | Time: 141.189sec
# Epoch:   78 | Training loss: 0.002 | Training Accuracy: 99.97 | Valid_loss: 0.018 | Valid_accuracy: 99.84 | Time: 140.885sec
# Epoch:   79 | Training loss: 0.002 | Training Accuracy: 99.97 | Valid_loss: 0.019 | Valid_accuracy: 99.88 | Time: 140.840sec
# Epoch:   80 | Training loss: 0.001 | Training Accuracy: 99.98 | Valid_loss: 0.022 | Valid_accuracy: 99.86 | Time: 140.841sec
# Epoch:   81 | Training loss: 0.001 | Training Accuracy: 99.98 | Valid_loss: 0.040 | Valid_accuracy: 99.58 | Time: 140.691sec
# Epoch:   82 | Training loss: 0.003 | Training Accuracy: 99.92 | Valid_loss: 0.027 | Valid_accuracy: 99.80 | Time: 140.611sec
# Epoch:   83 | Training loss: 0.002 | Training Accuracy: 99.95 | Valid_loss: 0.024 | Valid_accuracy: 99.85 | Time: 140.842sec
# Epoch:   84 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.033 | Valid_accuracy: 99.81 | Time: 140.668sec
# Epoch:   85 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.029 | Valid_accuracy: 99.83 | Time: 140.830sec
# Epoch:   86 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.033 | Valid_accuracy: 99.82 | Time: 140.815sec
# Epoch:   87 | Training loss: 0.001 | Training Accuracy: 99.98 | Valid_loss: 0.025 | Valid_accuracy: 99.71 | Time: 141.025sec
# Epoch:   88 | Training loss: 0.002 | Training Accuracy: 99.96 | Valid_loss: 0.031 | Valid_accuracy: 99.71 | Time: 140.627sec
# Epoch:   89 | Training loss: 0.002 | Training Accuracy: 99.94 | Valid_loss: 0.025 | Valid_accuracy: 99.78 | Time: 140.748sec
# Epoch:   90 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.024 | Valid_accuracy: 99.80 | Time: 140.804sec
# Epoch:   91 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.026 | Valid_accuracy: 99.79 | Time: 140.723sec
# Epoch:   92 | Training loss: 0.002 | Training Accuracy: 99.96 | Valid_loss: 0.022 | Valid_accuracy: 99.83 | Time: 140.927sec
# Epoch:   93 | Training loss: 0.006 | Training Accuracy: 99.93 | Valid_loss: 0.029 | Valid_accuracy: 99.72 | Time: 140.969sec
# Epoch:   94 | Training loss: 0.001 | Training Accuracy: 99.97 | Valid_loss: 0.031 | Valid_accuracy: 99.85 | Time: 140.812sec
# Epoch:   95 | Training loss: 0.001 | Training Accuracy: 99.96 | Valid_loss: 0.025 | Valid_accuracy: 99.85 | Time: 140.891sec
# Epoch:   96 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.039 | Valid_accuracy: 99.82 | Time: 141.335sec
# Epoch:   97 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.043 | Valid_accuracy: 99.82 | Time: 141.316sec
# Epoch:   98 | Training loss: 0.005 | Training Accuracy: 99.94 | Valid_loss: 0.024 | Valid_accuracy: 99.80 | Time: 141.269sec
# Epoch:   99 | Training loss: 0.001 | Training Accuracy: 99.97 | Valid_loss: 0.019 | Valid_accuracy: 99.82 | Time: 140.845sec
# Epoch:  100 | Training loss: 0.000 | Training Accuracy: 99.98 | Valid_loss: 0.033 | Valid_accuracy: 99.81 | Time: 140.585sec
# Epoch:  101 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.026 | Valid_accuracy: 99.83 | Time: 140.699sec
# Epoch:  102 | Training loss: 0.003 | Training Accuracy: 99.96 | Valid_loss: 0.132 | Valid_accuracy: 98.45 | Time: 141.441sec
# Epoch:  103 | Training loss: 0.003 | Training Accuracy: 99.94 | Valid_loss: 0.025 | Valid_accuracy: 99.63 | Time: 141.419sec
# Epoch:  104 | Training loss: 0.002 | Training Accuracy: 99.96 | Valid_loss: 0.030 | Valid_accuracy: 99.69 | Time: 141.593sec
# Epoch:  105 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.023 | Valid_accuracy: 99.80 | Time: 141.670sec
# Epoch:  106 | Training loss: 0.001 | Training Accuracy: 99.98 | Valid_loss: 0.037 | Valid_accuracy: 99.81 | Time: 141.547sec
# Epoch:  107 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.036 | Valid_accuracy: 99.79 | Time: 141.696sec
# Epoch:  108 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.037 | Valid_accuracy: 99.81 | Time: 141.605sec
# Epoch:  109 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.037 | Valid_accuracy: 99.82 | Time: 141.909sec
# Epoch:  110 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.037 | Valid_accuracy: 99.80 | Time: 141.801sec
# Epoch:  111 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.038 | Valid_accuracy: 99.83 | Time: 142.024sec
# Epoch:  112 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.036 | Valid_accuracy: 99.82 | Time: 141.855sec
# Epoch:  113 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.039 | Valid_accuracy: 99.82 | Time: 142.009sec
# Epoch:  114 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.038 | Valid_accuracy: 99.81 | Time: 141.979sec
# Epoch:  115 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.041 | Valid_accuracy: 99.83 | Time: 141.838sec
# Epoch:  116 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.038 | Valid_accuracy: 99.84 | Time: 141.867sec
# Epoch:  117 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.042 | Valid_accuracy: 99.84 | Time: 141.850sec
# Epoch:  118 | Training loss: 0.010 | Training Accuracy: 99.89 | Valid_loss: 0.039 | Valid_accuracy: 99.47 | Time: 141.830sec
# Epoch:  119 | Training loss: 0.007 | Training Accuracy: 99.91 | Valid_loss: 0.027 | Valid_accuracy: 99.67 | Time: 141.396sec
# Epoch:  120 | Training loss: 0.002 | Training Accuracy: 99.96 | Valid_loss: 0.035 | Valid_accuracy: 99.74 | Time: 141.225sec
# Epoch:  121 | Training loss: 0.001 | Training Accuracy: 99.96 | Valid_loss: 0.023 | Valid_accuracy: 99.82 | Time: 141.236sec
# Epoch:  122 | Training loss: 0.002 | Training Accuracy: 99.99 | Valid_loss: 0.031 | Valid_accuracy: 99.80 | Time: 141.520sec
# Epoch:  123 | Training loss: 0.001 | Training Accuracy: 99.97 | Valid_loss: 0.031 | Valid_accuracy: 99.80 | Time: 141.645sec
# Epoch:  124 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.045 | Valid_accuracy: 99.74 | Time: 141.690sec
# Epoch:  125 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.027 | Valid_accuracy: 99.80 | Time: 141.597sec
# Epoch:  126 | Training loss: 0.001 | Training Accuracy: 99.97 | Valid_loss: 0.026 | Valid_accuracy: 99.83 | Time: 141.226sec
# Epoch:  127 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.031 | Valid_accuracy: 99.82 | Time: 141.144sec
# Epoch:  128 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.028 | Valid_accuracy: 99.84 | Time: 141.260sec
# Epoch:  129 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.032 | Valid_accuracy: 99.84 | Time: 141.355sec
# Epoch:  130 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.031 | Valid_accuracy: 99.85 | Time: 141.461sec
# Epoch:  131 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.032 | Valid_accuracy: 99.84 | Time: 140.547sec
# Epoch:  132 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.046 | Valid_accuracy: 99.79 | Time: 139.775sec
# Epoch:  133 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.040 | Valid_accuracy: 99.82 | Time: 139.845sec
# Epoch:  134 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.046 | Valid_accuracy: 99.81 | Time: 140.021sec
# Epoch:  135 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.039 | Valid_accuracy: 99.82 | Time: 139.980sec
# Epoch:  136 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.041 | Valid_accuracy: 99.80 | Time: 139.948sec
# Epoch:  137 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.044 | Valid_accuracy: 99.80 | Time: 139.792sec
# Epoch:  138 | Training loss: 0.015 | Training Accuracy: 99.85 | Valid_loss: 0.026 | Valid_accuracy: 99.76 | Time: 139.852sec
# Epoch:  139 | Training loss: 0.002 | Training Accuracy: 99.96 | Valid_loss: 0.024 | Valid_accuracy: 99.78 | Time: 139.570sec
# Epoch:  140 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.027 | Valid_accuracy: 99.78 | Time: 139.526sec
# Epoch:  141 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.036 | Valid_accuracy: 99.80 | Time: 139.676sec
# Epoch:  142 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.046 | Valid_accuracy: 99.76 | Time: 140.153sec
# Epoch:  143 | Training loss: 0.004 | Training Accuracy: 99.97 | Valid_loss: 0.031 | Valid_accuracy: 99.80 | Time: 139.937sec
# Epoch:  144 | Training loss: 0.003 | Training Accuracy: 99.96 | Valid_loss: 0.032 | Valid_accuracy: 99.82 | Time: 139.983sec
# Epoch:  145 | Training loss: 0.002 | Training Accuracy: 99.98 | Valid_loss: 0.049 | Valid_accuracy: 99.79 | Time: 140.060sec
# Epoch:  146 | Training loss: 0.002 | Training Accuracy: 99.97 | Valid_loss: 0.029 | Valid_accuracy: 99.72 | Time: 139.935sec
# Epoch:  147 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.039 | Valid_accuracy: 99.81 | Time: 140.014sec
# Epoch:  148 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.037 | Valid_accuracy: 99.81 | Time: 139.933sec
# Epoch:  149 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.033 | Valid_accuracy: 99.82 | Time: 139.957sec
# Epoch:  150 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.047 | Valid_accuracy: 99.82 | Time: 139.999sec
# Epoch:  151 | Training loss: 0.003 | Training Accuracy: 99.94 | Valid_loss: 0.046 | Valid_accuracy: 99.81 | Time: 139.949sec
# Epoch:  152 | Training loss: 0.001 | Training Accuracy: 99.99 | Valid_loss: 0.029 | Valid_accuracy: 99.83 | Time: 139.960sec
# Epoch:  153 | Training loss: 0.002 | Training Accuracy: 99.98 | Valid_loss: 0.031 | Valid_accuracy: 99.73 | Time: 140.376sec
# Epoch:  154 | Training loss: 0.003 | Training Accuracy: 99.96 | Valid_loss: 0.023 | Valid_accuracy: 99.82 | Time: 140.194sec
# Epoch:  155 | Training loss: 0.001 | Training Accuracy: 99.97 | Valid_loss: 0.030 | Valid_accuracy: 99.83 | Time: 140.272sec
# Epoch:  156 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.035 | Valid_accuracy: 99.82 | Time: 139.788sec
# Epoch:  157 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.039 | Valid_accuracy: 99.81 | Time: 140.002sec
# Epoch:  158 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.058 | Valid_accuracy: 99.82 | Time: 139.985sec
# Epoch:  159 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.053 | Valid_accuracy: 99.83 | Time: 139.829sec
# Epoch:  160 | Training loss: 0.001 | Training Accuracy: 99.98 | Valid_loss: 0.060 | Valid_accuracy: 99.78 | Time: 139.965sec
# Epoch:  161 | Training loss: 0.001 | Training Accuracy: 99.99 | Valid_loss: 0.043 | Valid_accuracy: 99.86 | Time: 139.774sec
# Epoch:  162 | Training loss: 0.002 | Training Accuracy: 99.98 | Valid_loss: 0.047 | Valid_accuracy: 99.81 | Time: 139.951sec
# Epoch:  163 | Training loss: 0.002 | Training Accuracy: 99.97 | Valid_loss: 0.045 | Valid_accuracy: 99.65 | Time: 139.944sec
# Epoch:  164 | Training loss: 0.008 | Training Accuracy: 99.93 | Valid_loss: 0.033 | Valid_accuracy: 99.81 | Time: 139.944sec
# Epoch:  165 | Training loss: 0.004 | Training Accuracy: 99.96 | Valid_loss: 0.036 | Valid_accuracy: 99.83 | Time: 140.052sec
# Epoch:  166 | Training loss: 0.001 | Training Accuracy: 99.99 | Valid_loss: 0.049 | Valid_accuracy: 99.80 | Time: 139.943sec
# Epoch:  167 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.041 | Valid_accuracy: 99.80 | Time: 139.830sec
# Epoch:  168 | Training loss: 0.000 | Training Accuracy: 99.98 | Valid_loss: 0.039 | Valid_accuracy: 99.81 | Time: 139.814sec
# Epoch:  169 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.040 | Valid_accuracy: 99.81 | Time: 139.941sec
# Epoch:  170 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.043 | Valid_accuracy: 99.81 | Time: 139.577sec
# Epoch:  171 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.042 | Valid_accuracy: 99.81 | Time: 139.796sec
# Epoch:  172 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.073 | Valid_accuracy: 99.75 | Time: 140.101sec
# Epoch:  173 | Training loss: 0.005 | Training Accuracy: 99.95 | Valid_loss: 0.034 | Valid_accuracy: 99.75 | Time: 140.209sec
# Epoch:  174 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.052 | Valid_accuracy: 99.73 | Time: 140.006sec
# Epoch:  175 | Training loss: 0.000 | Training Accuracy: 99.98 | Valid_loss: 0.077 | Valid_accuracy: 99.73 | Time: 140.235sec
# Epoch:  176 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.061 | Valid_accuracy: 99.77 | Time: 140.162sec
# Epoch:  177 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.058 | Valid_accuracy: 99.77 | Time: 140.363sec
# Epoch:  178 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.057 | Valid_accuracy: 99.78 | Time: 140.145sec
# Epoch:  179 | Training loss: 0.001 | Training Accuracy: 99.99 | Valid_loss: 0.059 | Valid_accuracy: 99.73 | Time: 140.303sec
# Epoch:  180 | Training loss: 0.005 | Training Accuracy: 99.95 | Valid_loss: 0.026 | Valid_accuracy: 99.82 | Time: 140.382sec
# Epoch:  181 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.028 | Valid_accuracy: 99.84 | Time: 140.684sec
# Epoch:  182 | Training loss: 0.009 | Training Accuracy: 99.94 | Valid_loss: 0.025 | Valid_accuracy: 99.81 | Time: 140.450sec
# Epoch:  183 | Training loss: 0.000 | Training Accuracy: 99.99 | Valid_loss: 0.033 | Valid_accuracy: 99.84 | Time: 140.255sec
# Epoch:  184 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.034 | Valid_accuracy: 99.85 | Time: 140.007sec
# Epoch:  185 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.036 | Valid_accuracy: 99.85 | Time: 140.136sec
# Epoch:  186 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.039 | Valid_accuracy: 99.84 | Time: 140.485sec
# Epoch:  187 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.040 | Valid_accuracy: 99.84 | Time: 140.002sec
# Epoch:  188 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.038 | Valid_accuracy: 99.85 | Time: 140.113sec
# Epoch:  189 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.039 | Valid_accuracy: 99.84 | Time: 139.954sec
# Epoch:  190 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.040 | Valid_accuracy: 99.85 | Time: 140.435sec
# Epoch:  191 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.041 | Valid_accuracy: 99.84 | Time: 140.463sec
# Epoch:  192 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.042 | Valid_accuracy: 99.85 | Time: 140.542sec
# Epoch:  193 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.044 | Valid_accuracy: 99.85 | Time: 140.293sec
# Epoch:  194 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.044 | Valid_accuracy: 99.85 | Time: 140.295sec
# Epoch:  195 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.048 | Valid_accuracy: 99.85 | Time: 140.387sec
# Epoch:  196 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.053 | Valid_accuracy: 99.84 | Time: 140.259sec
# Epoch:  197 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.052 | Valid_accuracy: 99.85 | Time: 140.211sec
# Epoch:  198 | Training loss: 0.000 | Training Accuracy: 100.00 | Valid_loss: 0.051 | Valid_accuracy: 99.85 | Time: 140.371sec

# %%
#Plotting graphs
#Loss curves
plt.plot(Epochs, Training_loss, 'g', label='Training Loss')
plt.plot(Epochs, Validation_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('loss.png')
plt.show()

# %%
#Accuracy Curves 
plt.plot(Epochs, Training_accuracy, 'g', label='Training Accuracy')
plt.plot(Epochs, Validation_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('accuracy.png')
plt.show()
