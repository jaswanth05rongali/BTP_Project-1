# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, models
from torch.utils.data.sampler import SubsetRandomSampler
import os
import random
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from PIL import Image
from torch.autograd import Variable

# %%
def process_data(datadir, valid_size = 0.25, batch_size = 256):
    
    train_transforms = transforms.Compose([transforms.Resize(227),
                                               transforms.RandomRotation(degrees=30),
                                               transforms.RandomHorizontalFlip(), 
                                               transforms.ColorJitter(hue=.1, saturation=.1),
                                               transforms.ToTensor(),])
    test_transforms = transforms.Compose([transforms.Resize(227),transforms.ToTensor(),])
    
    train_data = datasets.ImageFolder(datadir, transform=train_transforms)
    test_data = datasets.ImageFolder(datadir, transform=test_transforms)
    
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size*num_train))
    np.random.shuffle(indices)
    train_idx,test_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(test_idx)
    
    trainloader = torch.utils.data.DataLoader(train_data, sampler = train_sampler, batch_size = batch_size)
    testloader = torch.utils.data.DataLoader(test_data, sampler = test_sampler, batch_size = batch_size)
    
    return trainloader,testloader

# %%
data_dir = "./data/SDNET2018"

train_loader,test_loader = process_data(data_dir)

# %%
class CNN_Model(nn.Module):
    def __init__(self):
        super().__init__()  
    
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=7, padding=1, stride=2),
            nn.LocalResponseNorm(size=5, alpha=0.0001, beta=0.75, k=2),
            nn.ReLU(inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(32, 48, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm2d(48),
            nn.ReLU(inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),          
            nn.Conv2d(48, 64, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),           
            nn.Conv2d(64, 96, kernel_size=5, padding=2, stride=1),
            nn.BatchNorm2d(96),
            nn.ReLU(inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(4704, 1024),
            nn.ReLU(inplace=False),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(1024, 128),
            nn.ReLU(inplace=False),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(128, 2),
        )    
        self.init_bias()
    
    def init_bias(self):
        for layer in self.features:
            if isinstance(layer, nn.Conv2d):
                nn.init.normal_(layer.weight, mean=0, std=0.01)
                nn.init.constant_(layer.bias, 0)        
    
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.shape[0], -1)
        x = self.classifier(x)
        return x

# %%
torch.cuda.empty_cache()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNN_Model().to(device)

# %%
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()

# %%
def accuracy(fp,y):
    preds = fp.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = correct.float()/preds.shape[0]
    return acc

# %%
def train(model, device, data_itr, optimizer, criterion):
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    for x,y in data_itr:
        x = x.to(device)
        y = y.to(device)
        
        optimizer.zero_grad()
        fp = model(x)
        loss = criterion(fp,y)
        acc = accuracy(fp,y)
        
        loss.backward()
        optimizer.step()
        
        epoch_loss += float(loss.item())
        epoch_acc += float(acc.item())
    return epoch_loss / len(data_itr), epoch_acc / len(data_itr)

# %%
def evaluate(model, device, data_itr, criterion):
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    with torch.no_grad():
        for x,y in data_itr:
            x = x.to(device)
            y = y.to(device)
            
            fp = model(x)
            loss = criterion(fp,y)
            acc = accuracy(fp,y)
            
            epoch_loss += loss.item()
            epoch_acc += acc.item()
    
    return epoch_loss / len(data_itr), epoch_acc / len(data_itr)

# %%
epochs = 1500
SAVE_DIR = 'models'
CKPT_SAVE_PATH = os.path.join(SAVE_DIR, 'cnn_crack_SDNET.pth.tar')
MODEL_SAVE_PATH = os.path.join(SAVE_DIR, 'cnn_crack_SDNET_model.pt')

best_val_loss = float('inf')

# if not os.path.isdir(f'{SAVE_DIR}'):
#     os.makedirs(f'{SAVE_DIR}')

Epochs = []
Training_loss = []
Training_accuracy = []
Validation_loss = []
Validation_accuracy = []
    
for epoch in range(epochs):
    to = time.time()
    train_loss,train_acc = train(model, device, train_loader, optimizer, criterion)
    val_loss,val_acc = evaluate(model, device, test_loader, criterion)
    tepoch = time.time() - to
    
    Epochs.append(epoch+1)
    Training_loss.append(train_loss)
    Training_accuracy.append(train_acc)
    Validation_accuracy.append(val_acc)
    Validation_loss.append(val_loss)
    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_epoch = epoch+1
        torch.save(model.state_dict(), MODEL_SAVE_PATH)
        
    if epoch%50 == 0:
        torch.save({
            'epoch': Epochs,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': Training_loss,
            'valid_loss': Validation_loss,
            'train_acc': Training_accuracy,
            'val_acc': Validation_accuracy,
            }, CKPT_SAVE_PATH)
        
    print("Epoch: %4d | Training loss: %.3f | Training Accuracy: %5.2f | Valid_loss: %.3f | Valid_accuracy: %5.2f | Time: %.3fsec" %(epoch+1, train_loss, train_acc*100, val_loss, val_acc*100, tepoch))
# Out:
# Epoch:    1 | Training loss: 0.448 | Training Accuracy: 84.72 | Valid_loss: 0.454 | Valid_accuracy: 84.47 | Time: 451.343sec
# Epoch:    2 | Training loss: 0.425 | Training Accuracy: 84.98 | Valid_loss: 0.443 | Valid_accuracy: 84.46 | Time: 448.559sec
# Epoch:    3 | Training loss: 0.420 | Training Accuracy: 85.00 | Valid_loss: 0.412 | Valid_accuracy: 84.46 | Time: 449.455sec
# Epoch:    4 | Training loss: 0.415 | Training Accuracy: 85.03 | Valid_loss: 0.444 | Valid_accuracy: 84.48 | Time: 452.559sec
# Epoch:    5 | Training loss: 0.405 | Training Accuracy: 85.09 | Valid_loss: 0.483 | Valid_accuracy: 84.47 | Time: 447.560sec
# Epoch:    6 | Training loss: 0.394 | Training Accuracy: 85.30 | Valid_loss: 0.417 | Valid_accuracy: 85.05 | Time: 451.167sec
# Epoch:    7 | Training loss: 0.383 | Training Accuracy: 85.64 | Valid_loss: 0.440 | Valid_accuracy: 84.98 | Time: 452.169sec
# Epoch:    8 | Training loss: 0.379 | Training Accuracy: 85.89 | Valid_loss: 0.384 | Valid_accuracy: 85.52 | Time: 454.016sec
# Epoch:    9 | Training loss: 0.373 | Training Accuracy: 86.05 | Valid_loss: 0.373 | Valid_accuracy: 85.87 | Time: 451.179sec
# Epoch:   10 | Training loss: 0.363 | Training Accuracy: 86.44 | Valid_loss: 0.498 | Valid_accuracy: 85.17 | Time: 455.992sec
# Epoch:   11 | Training loss: 0.355 | Training Accuracy: 86.80 | Valid_loss: 0.720 | Valid_accuracy: 84.88 | Time: 455.754sec
# Epoch:   12 | Training loss: 0.347 | Training Accuracy: 87.16 | Valid_loss: 0.435 | Valid_accuracy: 86.00 | Time: 454.810sec
# Epoch:   13 | Training loss: 0.341 | Training Accuracy: 87.40 | Valid_loss: 0.427 | Valid_accuracy: 86.59 | Time: 458.229sec
# Epoch:  209 | Training loss: 0.115 | Training Accuracy: 95.83 | Valid_loss: 0.290 | Valid_accuracy: 92.11 | Time: 459.356sec
# Epoch:  210 | Training loss: 0.116 | Training Accuracy: 95.77 | Valid_loss: 0.325 | Valid_accuracy: 91.12 | Time: 459.299sec
# Epoch:  211 | Training loss: 0.114 | Training Accuracy: 95.92 | Valid_loss: 0.350 | Valid_accuracy: 91.25 | Time: 456.158sec
# Epoch:  212 | Training loss: 0.115 | Training Accuracy: 95.76 | Valid_loss: 0.300 | Valid_accuracy: 91.92 | Time: 453.404sec
# Epoch:  213 | Training loss: 0.114 | Training Accuracy: 95.82 | Valid_loss: 0.394 | Valid_accuracy: 89.85 | Time: 455.334sec
# Epoch:  214 | Training loss: 0.113 | Training Accuracy: 95.93 | Valid_loss: 0.423 | Valid_accuracy: 91.57 | Time: 448.271sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-1306c4404ec7> in <module>
#      18     to = time.time()
#      19     train_loss,train_acc = train(model, device, train_loader, optimizer, criterion)
# ---> 20     val_loss,val_acc = evaluate(model, device, test_loader, criterion)
#      21     tepoch = time.time() - to
#      22
#
# <ipython-input-9-3445a2214038> in evaluate(model, device, data_itr, criterion)
#       5     model.eval()
#       6     with torch.no_grad():
# ----> 7         for x,y in data_itr:
#       8             x = x.to(device)
#       9             y = y.to(device)
#
# ~/.local/lib/python3.5/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     344     def __next__(self):
#     345         index = self._next_index()  # may raise StopIteration
# --> 346         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     347         if self._pin_memory:
#     348             data = _utils.pin_memory.pin_memory(data)
#
# ~/.local/lib/python3.5/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
# ---> 47         return self.collate_fn(data)
#
# ~/.local/lib/python3.5/site-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      77     elif isinstance(elem, container_abcs.Sequence):
#      78         transposed = zip(*batch)
# ---> 79         return [default_collate(samples) for samples in transposed]
#      80
#      81     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# ~/.local/lib/python3.5/site-packages/torch/utils/data/_utils/collate.py in <listcomp>(.0)
#      77     elif isinstance(elem, container_abcs.Sequence):
#      78         transposed = zip(*batch)
# ---> 79         return [default_collate(samples) for samples in transposed]
#      80
#      81     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# ~/.local/lib/python3.5/site-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      53             storage = elem.storage()._new_shared(numel)
#      54             out = elem.new(storage)
# ---> 55         return torch.stack(batch, 0, out=out)
#      56     elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
#      57             and elem_type.__name__ != 'string_':
#
# KeyboardInterrupt:

# %%
#Plotting graphs
#Loss curves
plt.plot(Epochs, Training_loss, 'g', label='Training Loss')
plt.plot(Epochs, Validation_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('SDNET_loss.png')
plt.show()

# %%
#Accuracy Curves 
plt.plot(Epochs, Training_accuracy, 'g', label='Training Accuracy')
plt.plot(Epochs, Validation_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('SDNET_accuracy.png')
plt.show()

# %%
checkpoint = torch.load('./models/cnn_crack_SDNET.pth.tar')
model.load_state_dict(checkpoint['model_state_dict'])
model.to('cpu')
model.eval()
with torch.no_grad():
    for x,y in test_loader:
        x = x.to('cpu')
        y = y.to('cpu')
        fp = model(x)
        y_pred = fp.max(1, keepdim=True)[1]
        print('Accuracy Score: ', accuracy_score(y,y_pred))
        print(confusion_matrix(y,y_pred))
        print(classification_report(y,y_pred))
# Out:
# Accuracy Score:  0.90625
# [[ 23  18]
#  [  6 209]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.56      0.66        41
#            1       0.92      0.97      0.95       215
#
#     accuracy                           0.91       256
#    macro avg       0.86      0.77      0.80       256
# weighted avg       0.90      0.91      0.90       256
#
# Accuracy Score:  0.94140625
# [[ 22  11]
#  [  4 219]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.67      0.75        33
#            1       0.95      0.98      0.97       223
#
#     accuracy                           0.94       256
#    macro avg       0.90      0.82      0.86       256
# weighted avg       0.94      0.94      0.94       256
#
# Accuracy Score:  0.92578125
# [[ 24  15]
#  [  4 213]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.62      0.72        39
#            1       0.93      0.98      0.96       217
#
#     accuracy                           0.93       256
#    macro avg       0.90      0.80      0.84       256
# weighted avg       0.92      0.93      0.92       256
#
# Accuracy Score:  0.94921875
# [[ 19  12]
#  [  1 224]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.61      0.75        31
#            1       0.95      1.00      0.97       225
#
#     accuracy                           0.95       256
#    macro avg       0.95      0.80      0.86       256
# weighted avg       0.95      0.95      0.94       256
#
# Accuracy Score:  0.9453125
# [[ 22   8]
#  [  6 220]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76        30
#            1       0.96      0.97      0.97       226
#
#     accuracy                           0.95       256
#    macro avg       0.88      0.85      0.86       256
# weighted avg       0.94      0.95      0.94       256
#
# Accuracy Score:  0.890625
# [[ 22  24]
#  [  4 206]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.48      0.61        46
#            1       0.90      0.98      0.94       210
#
#     accuracy                           0.89       256
#    macro avg       0.87      0.73      0.77       256
# weighted avg       0.89      0.89      0.88       256
#
# Accuracy Score:  0.89453125
# [[ 25  23]
#  [  4 204]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.52      0.65        48
#            1       0.90      0.98      0.94       208
#
#     accuracy                           0.89       256
#    macro avg       0.88      0.75      0.79       256
# weighted avg       0.89      0.89      0.88       256
#
# Accuracy Score:  0.8984375
# [[ 13  23]
#  [  3 217]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.36      0.50        36
#            1       0.90      0.99      0.94       220
#
#     accuracy                           0.90       256
#    macro avg       0.86      0.67      0.72       256
# weighted avg       0.89      0.90      0.88       256
#
# Accuracy Score:  0.91796875
# [[ 20  15]
#  [  6 215]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.57      0.66        35
#            1       0.93      0.97      0.95       221
#
#     accuracy                           0.92       256
#    macro avg       0.85      0.77      0.80       256
# weighted avg       0.91      0.92      0.91       256
#
# Accuracy Score:  0.9140625
# [[ 30  16]
#  [  6 204]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.65      0.73        46
#            1       0.93      0.97      0.95       210
#
#     accuracy                           0.91       256
#    macro avg       0.88      0.81      0.84       256
# weighted avg       0.91      0.91      0.91       256
#
# Accuracy Score:  0.90625
# [[ 24  19]
#  [  5 208]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.56      0.67        43
#            1       0.92      0.98      0.95       213
#
#     accuracy                           0.91       256
#    macro avg       0.87      0.77      0.81       256
# weighted avg       0.90      0.91      0.90       256
#
# Accuracy Score:  0.90234375
# [[ 42  20]
#  [  5 189]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.68      0.77        62
#            1       0.90      0.97      0.94       194
#
#     accuracy                           0.90       256
#    macro avg       0.90      0.83      0.85       256
# weighted avg       0.90      0.90      0.90       256
#
# Accuracy Score:  0.92578125
# [[ 20  16]
#  [  3 217]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.56      0.68        36
#            1       0.93      0.99      0.96       220
#
#     accuracy                           0.93       256
#    macro avg       0.90      0.77      0.82       256
# weighted avg       0.92      0.93      0.92       256
#
# Accuracy Score:  0.921875
# [[ 29  11]
#  [  9 207]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74        40
#            1       0.95      0.96      0.95       216
#
#     accuracy                           0.92       256
#    macro avg       0.86      0.84      0.85       256
# weighted avg       0.92      0.92      0.92       256
#
# Accuracy Score:  0.9140625
# [[ 34  17]
#  [  5 200]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.67      0.76        51
#            1       0.92      0.98      0.95       205
#
#     accuracy                           0.91       256
#    macro avg       0.90      0.82      0.85       256
# weighted avg       0.91      0.91      0.91       256
#
# Accuracy Score:  0.9140625
# [[ 22  16]
#  [  6 212]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.58      0.67        38
#            1       0.93      0.97      0.95       218
#
#     accuracy                           0.91       256
#    macro avg       0.86      0.78      0.81       256
# weighted avg       0.91      0.91      0.91       256
#
# Accuracy Score:  0.91015625
# [[ 28  18]
#  [  5 205]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.61      0.71        46
#            1       0.92      0.98      0.95       210
#
#     accuracy                           0.91       256
#    macro avg       0.88      0.79      0.83       256
# weighted avg       0.91      0.91      0.90       256
#
# Accuracy Score:  0.88671875
# [[ 21  19]
#  [ 10 206]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.53      0.59        40
#            1       0.92      0.95      0.93       216
#
#     accuracy                           0.89       256
#    macro avg       0.80      0.74      0.76       256
# weighted avg       0.88      0.89      0.88       256
#
# Accuracy Score:  0.87109375
# [[ 13  22]
#  [ 11 210]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.37      0.44        35
#            1       0.91      0.95      0.93       221
#
#     accuracy                           0.87       256
#    macro avg       0.72      0.66      0.68       256
# weighted avg       0.86      0.87      0.86       256
#
# Accuracy Score:  0.9296875
# [[ 17  10]
#  [  8 221]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.63      0.65        27
#            1       0.96      0.97      0.96       229
#
#     accuracy                           0.93       256
#    macro avg       0.82      0.80      0.81       256
# weighted avg       0.93      0.93      0.93       256
#
# Accuracy Score:  0.9296875
# [[ 26  14]
#  [  4 212]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.65      0.74        40
#            1       0.94      0.98      0.96       216
#
#     accuracy                           0.93       256
#    macro avg       0.90      0.82      0.85       256
# weighted avg       0.93      0.93      0.93       256
#
# Accuracy Score:  0.92578125
# [[ 18  15]
#  [  4 219]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.55      0.65        33
#            1       0.94      0.98      0.96       223
#
#     accuracy                           0.93       256
#    macro avg       0.88      0.76      0.81       256
# weighted avg       0.92      0.93      0.92       256
# Accuracy Score:  0.921875
# [[ 31  15]
#  [  5 205]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.76        46
#            1       0.93      0.98      0.95       210
#
#     accuracy                           0.92       256
#    macro avg       0.90      0.83      0.85       256
# weighted avg       0.92      0.92      0.92       256
#
# Accuracy Score:  0.9609375
# [[ 31   9]
#  [  1 215]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86        40
#            1       0.96      1.00      0.98       216
#
#     accuracy                           0.96       256
#    macro avg       0.96      0.89      0.92       256
# weighted avg       0.96      0.96      0.96       256
#
# Accuracy Score:  0.91796875
# [[ 18  14]
#  [  7 217]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.56      0.63        32
#            1       0.94      0.97      0.95       224
#
#     accuracy                           0.92       256
#    macro avg       0.83      0.77      0.79       256
# weighted avg       0.91      0.92      0.91       256
#
# Accuracy Score:  0.93359375
# [[ 30  14]
#  [  3 209]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.68      0.78        44
#            1       0.94      0.99      0.96       212
#
#     accuracy                           0.93       256
#    macro avg       0.92      0.83      0.87       256
# weighted avg       0.93      0.93      0.93       256
#
# Accuracy Score:  0.9140625
# [[ 21  15]
#  [  7 213]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.58      0.66        36
#            1       0.93      0.97      0.95       220
#
#     accuracy                           0.91       256
#    macro avg       0.84      0.78      0.80       256
# weighted avg       0.91      0.91      0.91       256
#
# Accuracy Score:  0.953125
# [[ 21   9]
#  [  3 223]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        30
#            1       0.96      0.99      0.97       226
#
#     accuracy                           0.95       256
#    macro avg       0.92      0.84      0.88       256
# weighted avg       0.95      0.95      0.95       256
#
# Accuracy Score:  0.90625
# [[ 27  20]
#  [  4 205]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.57      0.69        47
#            1       0.91      0.98      0.94       209
#
#     accuracy                           0.91       256
#    macro avg       0.89      0.78      0.82       256
# weighted avg       0.90      0.91      0.90       256
#
# Accuracy Score:  0.92578125
# [[ 33  17]
#  [  2 204]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.66      0.78        50
#            1       0.92      0.99      0.96       206
#
#     accuracy                           0.93       256
#    macro avg       0.93      0.83      0.87       256
# weighted avg       0.93      0.93      0.92       256
#
# Accuracy Score:  0.921875
# [[ 34  16]
#  [  4 202]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.68      0.77        50
#            1       0.93      0.98      0.95       206
#
#     accuracy                           0.92       256
#    macro avg       0.91      0.83      0.86       256
# weighted avg       0.92      0.92      0.92       256
#
# Accuracy Score:  0.921875
# [[ 25  15]
#  [  5 211]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.62      0.71        40
#            1       0.93      0.98      0.95       216
#
#     accuracy                           0.92       256
#    macro avg       0.88      0.80      0.83       256
# weighted avg       0.92      0.92      0.92       256
#
# Accuracy Score:  0.91796875
# [[ 29  16]
#  [  5 206]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.64      0.73        45
#            1       0.93      0.98      0.95       211
#
#     accuracy                           0.92       256
#    macro avg       0.89      0.81      0.84       256
# weighted avg       0.91      0.92      0.91       256
#
# Accuracy Score:  0.89453125
# [[ 21  20]
#  [  7 208]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.51      0.61        41
#            1       0.91      0.97      0.94       215
#
#     accuracy                           0.89       256
#    macro avg       0.83      0.74      0.77       256
# weighted avg       0.89      0.89      0.89       256
#
# Accuracy Score:  0.921875
# [[ 29  16]
#  [  4 207]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74        45
#            1       0.93      0.98      0.95       211
#
#     accuracy                           0.92       256
#    macro avg       0.90      0.81      0.85       256
# weighted avg       0.92      0.92      0.92       256
#
# Accuracy Score:  0.91796875
# [[ 20  17]
#  [  4 215]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.54      0.66        37
#            1       0.93      0.98      0.95       219
#
#     accuracy                           0.92       256
#    macro avg       0.88      0.76      0.80       256
# weighted avg       0.91      0.92      0.91       256
#
# Accuracy Score:  0.921875
# [[ 24  16]
#  [  4 212]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71        40
#            1       0.93      0.98      0.95       216
#
#     accuracy                           0.92       256
#    macro avg       0.89      0.79      0.83       256
# weighted avg       0.92      0.92      0.92       256
#
# Accuracy Score:  0.890625
# [[ 27  22]
#  [  6 201]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.55      0.66        49
#            1       0.90      0.97      0.93       207
#
#     accuracy                           0.89       256
#    macro avg       0.86      0.76      0.80       256
# weighted avg       0.89      0.89      0.88       256
#
# Accuracy Score:  0.91796875
# [[ 17  19]
#  [  2 218]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.47      0.62        36
#            1       0.92      0.99      0.95       220
#
#     accuracy                           0.92       256
#    macro avg       0.91      0.73      0.79       256
# weighted avg       0.92      0.92      0.91       256
#
# Accuracy Score:  0.9453125
# [[ 21  11]
#  [  3 221]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.66      0.75        32
#            1       0.95      0.99      0.97       224
#
#     accuracy                           0.95       256
#    macro avg       0.91      0.82      0.86       256
# weighted avg       0.94      0.95      0.94       256
#
# Accuracy Score:  0.90625
# [[ 28  18]
#  [  6 204]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.61      0.70        46
#            1       0.92      0.97      0.94       210
#
#     accuracy                           0.91       256
#    macro avg       0.87      0.79      0.82       256
# weighted avg       0.90      0.91      0.90       256
#
# Accuracy Score:  0.91015625
# [[ 21  17]
#  [  6 212]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.55      0.65        38
#            1       0.93      0.97      0.95       218
#
#     accuracy                           0.91       256
#    macro avg       0.85      0.76      0.80       256
# weighted avg       0.90      0.91      0.90       256
#
# Accuracy Score:  0.8828125
# [[ 22  25]
#  [  5 204]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.47      0.59        47
#            1       0.89      0.98      0.93       209
#
#     accuracy                           0.88       256
#    macro avg       0.85      0.72      0.76       256
# weighted avg       0.88      0.88      0.87       256
#
# Accuracy Score:  0.92578125
# [[ 23  11]
#  [  8 214]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.68      0.71        34
#            1       0.95      0.96      0.96       222
#
#     accuracy                           0.93       256
#    macro avg       0.85      0.82      0.83       256
# weighted avg       0.92      0.93      0.92       256
# Accuracy Score:  0.921875
# [[ 19  14]
#  [  6 217]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.58      0.66        33
#            1       0.94      0.97      0.96       223
#
#     accuracy                           0.92       256
#    macro avg       0.85      0.77      0.81       256
# weighted avg       0.92      0.92      0.92       256
#
# Accuracy Score:  0.953125
# [[ 22   9]
#  [  3 222]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.79        31
#            1       0.96      0.99      0.97       225
#
#     accuracy                           0.95       256
#    macro avg       0.92      0.85      0.88       256
# weighted avg       0.95      0.95      0.95       256
#
# Accuracy Score:  0.94140625
# [[ 20  10]
#  [  5 221]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        30
#            1       0.96      0.98      0.97       226
#
#     accuracy                           0.94       256
#    macro avg       0.88      0.82      0.85       256
# weighted avg       0.94      0.94      0.94       256
#
# Accuracy Score:  0.91796875
# [[ 25  15]
#  [  6 210]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.62      0.70        40
#            1       0.93      0.97      0.95       216
#
#     accuracy                           0.92       256
#    macro avg       0.87      0.80      0.83       256
# weighted avg       0.91      0.92      0.91       256
#
# Accuracy Score:  0.92578125
# [[ 20  14]
#  [  5 217]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.59      0.68        34
#            1       0.94      0.98      0.96       222
#
#     accuracy                           0.93       256
#    macro avg       0.87      0.78      0.82       256
# weighted avg       0.92      0.93      0.92       256
#
# Accuracy Score:  0.93359375
# [[ 26  14]
#  [  3 213]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.65      0.75        40
#            1       0.94      0.99      0.96       216
#
#     accuracy                           0.93       256
#    macro avg       0.92      0.82      0.86       256
# weighted avg       0.93      0.93      0.93       256
#
# Accuracy Score:  0.8984375
# [[ 21  19]
#  [  7 209]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.53      0.62        40
#            1       0.92      0.97      0.94       216
#
#     accuracy                           0.90       256
#    macro avg       0.83      0.75      0.78       256
# weighted avg       0.89      0.90      0.89       256
#
# Accuracy Score:  0.921875
# [[ 28  15]
#  [  5 208]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.65      0.74        43
#            1       0.93      0.98      0.95       213
#
#     accuracy                           0.92       256
#    macro avg       0.89      0.81      0.85       256
# weighted avg       0.92      0.92      0.92       256
#
# Accuracy Score:  0.91796875
# [[ 30  15]
#  [  6 205]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.67      0.74        45
#            1       0.93      0.97      0.95       211
#
#     accuracy                           0.92       256
#    macro avg       0.88      0.82      0.85       256
# weighted avg       0.91      0.92      0.91       256
#
# Accuracy Score:  0.94921875
# [[ 33  11]
#  [  2 210]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.75      0.84        44
#            1       0.95      0.99      0.97       212
#
#     accuracy                           0.95       256
#    macro avg       0.95      0.87      0.90       256
# weighted avg       0.95      0.95      0.95       256
#
# Accuracy Score:  0.949748743718593
# [[ 11   6]
#  [  4 178]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.65      0.69        17
#            1       0.97      0.98      0.97       182
#
#     accuracy                           0.95       199
#    macro avg       0.85      0.81      0.83       199
# weighted avg       0.95      0.95      0.95       199

# %%
device = 'cpu'
checkpoint = torch.load('./models/cnn_crack_SDNET_200.pth.tar')
test_transforms = transforms.Compose([transforms.Resize(227),transforms.ToTensor(),])
model_predict = CNN_Model().to(device)
model_predict.load_state_dict(checkpoint['model_state_dict'])
model_predict = model_predict.eval()
image = Image.open('./test_images/test1.jpg')
image = image.resize((227,227))
image_tensor = test_transforms(image).float()
image_tensor = image_tensor.unsqueeze_(0)
inp = Variable(image_tensor)
inp = inp.to(device)
output = model_predict(inp)
index = output.data.cpu().numpy().argmax()
print(index)
# Out:
# 0
